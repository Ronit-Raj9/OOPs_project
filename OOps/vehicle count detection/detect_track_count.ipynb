# %%
#!pip install ultralytics

# %%
import ultralytics
ultralytics.__version__
# Out:
# '8.0.114'

# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import*

model=YOLO('yolov8s.pt')

# %%
paused = False

# Create a function to toggle the paused state
def toggle_pause():
    global paused
    paused = not paused

# %%
class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
tracker=Tracker()
count=0

# %%
cap=cv2.VideoCapture('small.mp4')

# %%
down={}
up={}

counter_down=[]
counter_up=[]

# %%
while True:
    # If not paused, read a frame from the video
    if not paused:
        ret, frame = cap.read()
        if not ret:
            break

        # Resize frame
        frame = cv2.resize(frame, (1020, 500))

        # Predict using YOLO model
        results = model.predict(frame)
        a = results[0].boxes.data.detach().cpu().numpy()

        # Convert predictions to DataFrame
        px = pd.DataFrame(a).astype("float")

        # Extract cars from predictions
        list = []
        for index, row in px.iterrows():
            x1 = int(row[0])
            y1 = int(row[1])
            x2 = int(row[2])
            y2 = int(row[3])
            d = int(row[5])
            c = class_list[d]
            if 'car' in c:
                list.append([x1, y1, x2, y2])

        # Update tracker
        bbox_id = tracker.update(list)

        # Process tracked objects
        for bbox in bbox_id:
            x3, y3, x4, y4, id = bbox
            cx = int(x3 + x4) // 2
            cy = int(y3 + y4) // 2

            # Define line positions
            red_line_y = 198
            blue_line_y = 268
            offset = 7

            # Count cars crossing lines
            if red_line_y < (cy + offset) and red_line_y > (cy - offset):
                down[id] = cy
            if id in down:
                if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
                    counter_down.append(id)
            if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
                up[id] = cy
            if id in up:
                if red_line_y < (cy + offset) and red_line_y > (cy - offset):
                    counter_up.append(id)

            # Draw lines and text on frame
            cv2.line(frame, (172, 198), (774, 198), (0, 0, 255), 3)
            cv2.putText(frame, 'red line', (172, 198), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
            cv2.line(frame, (8, 268), (927, 268), (255, 0, 0), 3)
            cv2.putText(frame, 'blue line', (8, 268), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
            cv2.putText(frame, 'going down - ' + str(len(counter_down)), (60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)
            cv2.putText(frame, 'going up - ' + str(len(counter_up)), (60, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
            cv2.imshow("frames", frame)

    # Wait for a key press
    key = cv2.waitKey(1) & 0xFF

    # If the 'p' key is pressed, toggle pause/play
    if key == ord('p'):
        toggle_pause()

    # If the 'Esc' key is pressed, exit
    if key == 27:
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 4 cars, 193.7ms
# Speed: 3.0ms preprocess, 193.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 212.5ms
# Speed: 5.0ms preprocess, 212.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 173.7ms
# Speed: 3.0ms preprocess, 173.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 173.8ms
# Speed: 4.0ms preprocess, 173.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 161.9ms
# Speed: 2.0ms preprocess, 161.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 167.3ms
# Speed: 2.2ms preprocess, 167.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 161.7ms
# Speed: 3.0ms preprocess, 161.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 186.1ms
# Speed: 1.6ms preprocess, 186.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 210.8ms
# Speed: 2.0ms preprocess, 210.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 206.9ms
# Speed: 4.0ms preprocess, 206.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 160.7ms
# Speed: 2.0ms preprocess, 160.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 156.0ms
# Speed: 2.0ms preprocess, 156.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 167.7ms
# Speed: 4.1ms preprocess, 167.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 156.5ms
# Speed: 3.1ms preprocess, 156.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 155.1ms
# Speed: 3.0ms preprocess, 155.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 152.5ms
# Speed: 2.0ms preprocess, 152.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 152.4ms
# Speed: 2.0ms preprocess, 152.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 157.1ms
# Speed: 3.0ms preprocess, 157.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 161.9ms
# Speed: 3.0ms preprocess, 161.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 205.6ms
# Speed: 3.0ms preprocess, 205.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 201.8ms
# Speed: 3.3ms preprocess, 201.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 158.9ms
# Speed: 2.1ms preprocess, 158.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 167.8ms
# Speed: 2.0ms preprocess, 167.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 158.9ms
# Speed: 2.0ms preprocess, 158.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 154.4ms
# Speed: 2.0ms preprocess, 154.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 1 traffic light, 160.0ms
# Speed: 3.0ms preprocess, 160.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 157.0ms
# Speed: 2.0ms preprocess, 157.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 1 traffic light, 151.7ms
# Speed: 3.0ms preprocess, 151.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 1 traffic light, 151.4ms
# Speed: 2.0ms preprocess, 151.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 traffic light, 158.4ms
# Speed: 3.0ms preprocess, 158.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 traffic light, 154.9ms
# Speed: 2.0ms preprocess, 154.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 traffic light, 176.0ms
# Speed: 4.0ms preprocess, 176.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 traffic light, 174.8ms
# Speed: 3.0ms preprocess, 174.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 traffic light, 165.3ms
# Speed: 2.0ms preprocess, 165.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640
ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 164.1ms
# Speed: 3.0ms preprocess, 164.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 162.0ms
# Speed: 2.0ms preprocess, 162.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 161.2ms
# Speed: 2.0ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 162.8ms
# Speed: 2.0ms preprocess, 162.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 159.1ms
# Speed: 3.0ms preprocess, 159.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 159.0ms
# Speed: 2.0ms preprocess, 159.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 162.2ms
# Speed: 2.0ms preprocess, 162.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 163.3ms
# Speed: 3.0ms preprocess, 163.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 164.9ms
# Speed: 3.5ms preprocess, 164.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 162.5ms
# Speed: 2.0ms preprocess, 162.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 158.1ms
# Speed: 3.0ms preprocess, 158.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 164.7ms
# Speed: 3.0ms preprocess, 164.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 190.9ms
# Speed: 2.0ms preprocess, 190.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 163.5ms
# Speed: 3.0ms preprocess, 163.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 160.1ms
# Speed: 2.0ms preprocess, 160.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 166.3ms
# Speed: 2.0ms preprocess, 166.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 169.5ms
# Speed: 3.0ms preprocess, 169.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 171.9ms
# Speed: 3.0ms preprocess, 171.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 172.6ms
# Speed: 3.0ms preprocess, 172.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 161.5ms
# Speed: 2.0ms preprocess, 161.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 186.2ms
# Speed: 2.0ms preprocess, 186.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 181.9ms
# Speed: 3.0ms preprocess, 181.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 1 train, 1 suitcase, 191.6ms
# Speed: 2.0ms preprocess, 191.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 169.3ms
# Speed: 3.0ms preprocess, 169.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 160.8ms
# Speed: 2.0ms preprocess, 160.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 166.2ms
# Speed: 3.0ms preprocess, 166.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 162.3ms
# Speed: 3.0ms preprocess, 162.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 171.4ms
# Speed: 3.1ms preprocess, 171.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 222.2ms
# Speed: 2.2ms preprocess, 222.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 161.2ms
# Speed: 3.0ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 164.0ms
# Speed: 2.0ms preprocess, 164.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 162.5ms
# Speed: 2.1ms preprocess, 162.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 172.7ms
# Speed: 2.7ms preprocess, 172.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 181.8ms
# Speed: 3.0ms preprocess, 181.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 176.5ms
# Speed: 2.1ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 164.9ms
# Speed: 2.0ms preprocess, 164.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# while True:    
#     ret,frame = cap.read()
#     if not ret:
#         break
#     count += 1
#     frame=cv2.resize(frame,(1020,500))
   

#     results=model.predict(frame)
#  #   print(results)
#     a=results[0].boxes.data
#     a = a.detach().cpu().numpy()  # added this line
#     px=pd.DataFrame(a).astype("float")
#     #print(px)

#     list=[]
             
#     for index,row in px.iterrows():
# #        print(row) 
#         x1=int(row[0])
#         y1=int(row[1])
#         x2=int(row[2])
#         y2=int(row[3])
#         d=int(row[5])
#         c=class_list[d]
#         if 'car' in c:
#             list.append([x1,y1,x2,y2])
#             #print(c)

#     bbox_id=tracker.update(list)
#     #print(bbox_id)
#     for bbox in bbox_id:
#         x3,y3,x4,y4,id=bbox
#         cx=int(x3+x4)//2
#         cy=int(y3+y4)//2

#         red_line_y=198
#         blue_line_y=268   
#         offset = 7
        
  

#         ''' both lines combined condition . First condition is for red line'''
#         ## condition for counting the cars which are entering from red line and exiting from blue line
#         if red_line_y < (cy + offset) and red_line_y > (cy - offset):
#           down[id]=cy   
#         if id in down:
#            if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):         
#              cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
#              cv2.putText(frame,str(id),(cx,cy),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)
#              #counter+=1
#              counter_down.append(id)  # get a list of the cars and buses which are entering the line red and exiting the line blue

#         # condition for cars entering from  blue line
#         if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
#           up[id]=cy   
#         if id in up:
#            if red_line_y < (cy + offset) and red_line_y > (cy - offset):         
#              cv2.circle(frame,(cx,cy),4,(0,0,255),-1)
#              cv2.putText(frame,str(id),(cx,cy),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,255,255),2)
#              #counter+=1
#              counter_up.append(id)  # get a list of the cars which are entering the line 1 and exiting the line 2 


    
#     text_color = (255,255,255)  # white color for text
#     red_color = (0, 0, 255)  # (B, G, R)   
#     blue_color = (255, 0, 0)  # (B, G, R)
#     green_color = (0, 255, 0)  # (B, G, R)  

#     cv2.line(frame,(150,198),(900,198),red_color,3)  #  starting cordinates and end of line cordinates
#     cv2.putText(frame,('red line'),(172,198),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)
    
#     # cv2.line(frame,(8,268),(927,268),blue_color,3)  # seconde line
#     # cv2.putText(frame,('blue line'),(8,268),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)    


#     downwards = (len(counter_down))
#     cv2.putText(frame,('going down - ')+ str(downwards),(60,40),cv2.FONT_HERSHEY_SIMPLEX, 0.5, green_color, 1, cv2.LINE_AA)    

    
#     upwards = (len(counter_up))
#     cv2.putText(frame,('going up - ')+ str(upwards),(60,60),cv2.FONT_HERSHEY_SIMPLEX, 0.5, text_color, 1, cv2.LINE_AA)  

#     cv2.imshow("frames", frame)
#     if cv2.waitKey(1)&0xFF==27:
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
# import cv2
# import pandas as pd
# from ultralytics import YOLO
# from tracker import*

# # Initialize YOLO model
# model = YOLO('yolov8s.pt')

# # Define class list
# class_list = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# # Initialize tracker
# tracker = Tracker()

# # Open video capture
# cap = cv2.VideoCapture('small.mp4')

# # Initialize variables
# down = {}
# up = {}
# counter_down = []
# counter_up = []
# paused = False

# # Function to toggle pause/play state
# def toggle_pause():
#     global paused
#     paused = not paused

# while True:
#     # If not paused, read a frame from the video
#     if not paused:
#         ret, frame = cap.read()
#         if not ret:
#             break

#         # Resize frame
#         frame = cv2.resize(frame, (1020, 500))

#         # Predict using YOLO model
#         results = model.predict(frame)
#         a = results[0].boxes.data.detach().cpu().numpy()

#         # Convert predictions to DataFrame
#         px = pd.DataFrame(a).astype("float")

#         # Extract cars from predictions
#         list = []
#         for index, row in px.iterrows():
#             x1 = int(row[0])
#             y1 = int(row[1])
#             x2 = int(row[2])
#             y2 = int(row[3])
#             d = int(row[5])
#             c = class_list[d]
#             if 'car' in c:
#                 list.append([x1, y1, x2, y2])

#         # Update tracker
#         bbox_id = tracker.update(list)

#         # Process tracked objects
#         for bbox in bbox_id:
#             x3, y3, x4, y4, id = bbox
#             cx = int(x3 + x4) // 2
#             cy = int(y3 + y4) // 2

#             # Define line positions
#             red_line_y = 198
#             blue_line_y = 268
#             offset = 7

#             # Count cars crossing lines
#             if red_line_y < (cy + offset) and red_line_y > (cy - offset):
#                 down[id] = cy
#             if id in down:
#                 if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
#                     counter_down.append(id)
#             if blue_line_y < (cy + offset) and blue_line_y > (cy - offset):
#                 up[id] = cy
#             if id in up:
#                 if red_line_y < (cy + offset) and red_line_y > (cy - offset):
#                     counter_up.append(id)

#             # Draw lines and text on frame
#             cv2.line(frame, (172, 198), (774, 198), (0, 0, 255), 3)
#             cv2.putText(frame, 'red line', (172, 198), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
#             cv2.line(frame, (8, 268), (927, 268), (255, 0, 0), 3)
#             cv2.putText(frame, 'blue line', (8, 268), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
#             cv2.putText(frame, 'going down - ' + str(len(counter_down)), (60, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)
#             cv2.putText(frame, 'going up - ' + str(len(counter_up)), (60, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
#             cv2.imshow("frames", frame)

#     # Wait for a key press
#     key = cv2.waitKey(1) & 0xFF

#     # If the 'p' key is pressed, toggle pause/play
#     if key == ord('p'):
#         toggle_pause()

#     # If the 'Esc' key is pressed, exit
#     if key == 27:
#         break

# # Release the video capture object and close all windows
# cap.release()
# cv2.destroyAllWindows()
